# %%
## 1 answer
## A PMF is a function that describes the probability of each possible outcome of a discrete random variable. 
## It maps each value of the random variable to the probability of that value occurring. 
## The PMF is defined only for discrete random variables, which take on a finite or countably infinite set of possible values.

##   A PDF, on the other hand, is a function that describes the probability distribution of a continuous random variable.
##   It represents the relative likelihood of different values of the random variable occurring within a certain interval. 
##   The PDF is defined for continuous random variables, which can take on any value within a certain range.
import numpy as np
import matplotlib.pyplot as plt

# Define a discrete random variable with values 1, 2, 3, 4, and 5
x = np.array([1, 2, 3, 4, 5])

# Define the probabilities of each value occurring
pmf = np.array([0.1, 0.2, 0.3, 0.2, 0.2])

# Plot the PMF
plt.stem(x, pmf)
plt.title('Probability Mass Function (PMF)')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.show()

# Define a continuous random variable with a normal distribution
x = np.linspace(-5, 5, 1000)
pdf = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * x**2)

# Plot the PDF
plt.plot(x, pdf)
plt.title('Probability Density Function (PDF)')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.show()

# %%
## 2 answer
## The CDF is defined for both discrete and continuous random variables. For a discrete random variable, 
## the CDF is defined as the sum of the probabilities of all values less than or equal to x.
## For a continuous random variable, the CDF is defined as the integral of the PDF from negative infinity to x.
import numpy as np
import matplotlib.pyplot as plt


mu = 0
sigma = 1
x = np.linspace(-5, 5, 1000)
pdf = (1 / np.sqrt(2 * np.pi * sigma**2)) * np.exp(-0.5 * ((x - mu) / sigma)**2)


cdf = np.cumsum(pdf) * (x[1] - x[0])

# Plot the PDF and CDF
fig, ax = plt.subplots()
ax.plot(x, pdf, label='PDF')
ax.plot(x, cdf, label='CDF')
ax.legend()
ax.set_title('Normal Distribution')
ax.set_xlabel('Value')
ax.set_ylabel('Probability')
plt.show()
## The CDF is useful because it allows us to compute the probability of X taking on any value within a certain range.
## We can also use the CDF to compute various statistical measures, such as the median and quartiles of the distribution.

# %% [raw]
# ## 3 answer
# The normal distribution, also known as the Gaussian distribution, is a commonly used probability distribution in statistics and data analysis. It is a bell-shaped curve that describes the distribution of many natural phenomena, such as height, weight, and test scores. Here are some examples of situations where the normal distribution might be used as a model:
#
# IQ scores: IQ scores are often assumed to follow a normal distribution, with a mean of 100 and a standard deviation of 15.
#
# Physical measurements: Physical measurements such as height, weight, and blood pressure often follow a normal distribution.
#
# Errors in measurement: Errors in measurement or experimental data are often assumed to be normally distributed, with a mean of zero and a certain standard deviation.
#
# Stock prices: Daily changes in stock prices are often modeled using a normal distribution.
#
# The normal distribution is characterized by two parameters: the mean (µ) and the standard deviation (σ). The mean specifies the center of the distribution, while the standard deviation specifies the spread of the distribution. Specifically, the parameters of the normal distribution relate to the shape of the distribution as follows:
#
# The mean determines the location of the peak of the distribution. If the mean is increased, the peak of the distribution moves to the right, and if it is decreased, the peak moves to the left.
#
# The standard deviation determines the spread of the distribution. A larger standard deviation results in a wider, flatter curve, while a smaller standard deviation results in a narrower, taller curve.
#
# The variance (σ^2) is a measure of the variability of the distribution, and is equal to the square of the standard deviation. A larger variance indicates a wider spread of the distribution, while a smaller variance indicates a narrower spread.

# %%
## 4 answer
## The normal distribution is an important probability distribution in statistics and data analysis.
## It has several important properties that make it useful in modeling real-world phenomena, such as:

## Symmetry: The normal distribution is symmetric around its mean, which makes it easy to compute probabilities and statistical measures.

## Central limit theorem: The normal distribution is a key component of the central limit theorem,
## which states that the distribution of the sum or average of a large number of independent and identically distributed random variables approaches a normal distribution.

## Common occurrence: Many real-world phenomena follow a normal distribution, such as height, weight, and test scores.
## example:- height of people in population
import numpy as np
import matplotlib.pyplot as plt

# Define a population of heights with mean 170 cm and standard deviation 5 cm
mu = 170
sigma = 5
heights = np.random.normal(mu, sigma, size=10000)

# Plot the distribution of heights
fig, ax = plt.subplots()
ax.hist(heights, bins=50)
ax.set_title('Distribution of Heights')
ax.set_xlabel('Height (cm)')
ax.set_ylabel('Frequency')
plt.show()

# %%
## 5 answer
## The Bernoulli distribution is a discrete probability distribution that describes the probability of a single binary event with two possible outcomes, typically labeled as success and failure. 
## The distribution is characterized by a single parameter p, which represents the probability of success
## examples:- bernouli distribution
import numpy as np
import matplotlib.pyplot as plt

# Define the probability of success
p = 0.5

# Generate a random sample of 1000 trials from a Bernoulli distribution
trials = np.random.binomial(1, p, size=1000)

# Plot the distribution of the sample
fig, ax = plt.subplots()
ax.hist(trials)
ax.set_title('Distribution of Bernoulli Trials')
ax.set_xlabel('Outcome')
ax.set_ylabel('Frequency')
ax.set_xticks([0, 1])
ax.set_xticklabels(['Failure', 'Success'])
plt.show()
## The main difference between the Bernoulli distribution and the binomial distribution is that the Bernoulli distribution models a single trial or event,
## while the binomial distribution models the number of successes in a fixed number of independent Bernoulli trials.
## The binomial distribution is characterized by two parameters: the probability of success p and the number of trials n.
## examples :- Binomial distribution
import numpy as np
import matplotlib.pyplot as plt

# Define the number of trials and the probability of success
n = 10
p = 0.5

# Generate a random sample of 1000 trials from a binomial distribution
trials = np.random.binomial(n, p, size=1000)

# Plot the distribution of the sample
fig, ax = plt.subplots()
ax.hist(trials, bins=range(n+2))
ax.set_title('Distribution of Binomial Trials')
ax.set_xlabel('Number of Successes')
ax.set_ylabel('Frequency')
plt.show()

# %%
## 6 answer
from scipy.stats import norm

mu = 50
sigma = 10
x = 60

# Calculate the z-score
z = (x - mu) / sigma

# Calculate the probability using the cumulative distribution function (CDF)
p = 1 - norm.cdf(z)

print(f"The probability of a randomly selected observation being greater than 60 is {p:.4f}")
# Out:
# The probability of a randomly selected observation being greater than 60 is 0.1587

# %%
## 7 answer
## The uniform distribution is a continuous probability distribution that has a constant probability density function over a specific interval. 
## In other words, all values in the interval have an equal chance of being selected.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Define the lower and upper boundaries
lower_bound = 0
upper_bound = 10

# Create a uniform distribution object
uniform_dist = uniform(loc=lower_bound, scale=upper_bound-lower_bound)

# Generate random samples from the distribution
samples = uniform_dist.rvs(size=1000)

# Plot the probability density function
x = np.linspace(lower_bound, upper_bound, 100)
pdf = uniform_dist.pdf(x)
plt.plot(x, pdf)
plt.xlabel('x')
plt.ylabel('PDF')
plt.title('Uniform Distribution')
plt.show()

# %% [raw]
# ## 8 answer
# The z-score, also known as the standard score, is a measure of how many standard deviations a data point is from the mean of its distribution. The formula for calculating the z-score of a data point is:
#
# z = (x - mu) / sigma
#
# Impotrance:- The z-score is important because it allows us to standardize different sets of data and compare them on a common scale. By calculating the z-score for each data point, we can determine how far away from the mean each value is, in terms of standard deviations. This can be useful in many applications, such as hypothesis testing, quality control, and data analysis.

# %% [raw]
# ## 9 answer
# The Central Limit Theorem (CLT) is a fundamental concept in probability theory and statistics. It states that, under certain conditions, the sum or average of a large number of independent and identically distributed random variables will tend to follow a normal distribution, regardless of the underlying distribution of the individual variables. In other words, the distribution of sample means becomes approximately normal as the sample size increases, regardless of the distribution of the population.
#
# The significance of the Central Limit Theorem lies in its wide range of applications. It is a key concept in statistical inference, which involves using sample data to draw conclusions about a population. The CLT allows us to make assumptions about the distribution of sample means, which in turn allows us to make probabilistic statements about the population as a whole. It is used in hypothesis testing, confidence intervals, and in many other statistical applications.

# %% [raw]
# ## 10 answer
# The Central Limit Theorem (CLT) is a fundamental concept in probability theory and statistics, and it has certain assumptions that must be met in order to be applied. These assumptions are:
#
# Independence: The samples or observations in the dataset must be independent of each other. That is, the value of one sample should not influence the value of another sample.
#
# Random sampling: The samples must be selected randomly from the population, so that each observation has an equal chance of being selected.
#
# Sample size: The sample size should be sufficiently large. There is no strict cutoff for what constitutes a "sufficiently large" sample size, but generally, a sample size of at least 30 is considered large enough to apply the CLT.
#
# Finite variance: The population from which the samples are drawn must have a finite variance. In practice, this assumption is often met, as many real-world datasets have finite variances.
